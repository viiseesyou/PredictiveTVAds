# %% [markdown]
# ## Важность признаков (LightGBM)

# %%
feature_importance = best_model.feature_importances_
feat_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importance})
feat_df.sort_values(by='Importance', ascending=False, inplace=True)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feat_df)
plt.title("LightGBM Feature Importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Важность признаков (CatBoost)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Получаем важность
feature_importance = best_catboost.get_feature_importance(prettified=True)

# Визуализация
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Importances',
    y='Feature Id',
    data=feature_importance.sort_values(by='Importances', ascending=False)
)
plt.title("CatBoost — Важность признаков")
plt.xlabel("Важность")
plt.ylabel("Признак")
plt.tight_layout()
plt.show()
